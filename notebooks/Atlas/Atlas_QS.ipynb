# %%
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# ---

# %% [markdown]
# Atlas table :
#
# https://www.kwasan.kyoto-u.ac.jp/~kouui/spectra/sphinx/_build/html/RST/Atlas.html

# %% [markdown]
# TODO :
#
# modify
#
# - "3000-10000"
# - "10000-13400"
#
# from "observed wavelength" to "vacuum wavelength".
#
# - "1609-3000" : SOLSTICE --> XPS
#
# - Ca II level energy --> NIST data
#
# - program : vacuum wavelength <--> wavelength in air

# %% [markdown]
# TODO
#
# 1. option : wavelength in air

# %% [markdown]
# ---

# %%
atlas = np.load("../../data/intensity/atlas/QS/atlas_QS.npy")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f3d141215bcd> in <module>()
# ----> 1 atlas = np.load("../../data/intensity/atlas/QS/atlas_QS.npy")
#
# NameError: name 'np' is not defined

# %%
fig ,ax = plt.subplots(1,1, figsize=(6,4), dpi=150)

ax.plot(atlas[0,:], atlas[1,:], "k-", linewidth=0.7)

ax.set_xlabel("Wavelength[$\AA$]")
ax.set_ylabel("Intensity[$erg/cm^{2}/Sr/cm/s$]")

#ax.set_xlim(1200,1230)
#ax.set_yscale("log")
#ax.set_xlim(120, 210)
#ax.set_xlim(320, 410)
#ax.set_xlim(430, 520)
#ax.set_xlim(700, 830)
#ax.set_xlim(910, 1100)
ax.set_xlim(6550, 6580)
plt.show()

# %%
atlas.shape
# Out:
# (2, 4158160)
