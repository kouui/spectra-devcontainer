# %% [markdown]
# # He plasma
#
# - 2022.09.03    u.k., k.i.
# - 2022.09.10    k.i., t.k.   include plasma measurement
# - 2023.04.01    k.i., u.k.   ion temperature and fixed ionization ratio
# - 2023.04.29    k.i., u.k.   given Ne, Te

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import numpy as np

#%matplotlib inline
#%matplotlib qt
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
# %load_ext autoreload
# %autoreload 2

from spectra.ImportAll import *
import warnings
warnings.simplefilter('ignore', UserWarning)
warnings.simplefilter('ignore', DeprecationWarning)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from spectra.Struct import Atom, Atmosphere, Radiation
from spectra.Atomic import Collision, SEsolver, ContinuumOpacity, BasicP
from spectra.Util import HelpUtil
from spectra.Visual import Plotting  #, Grotrian
from spectra.Atomic import LTELib
from spectra.Function.SEquil import SELib
#from spectra.Function.Icp import SELib    # T_e != T_i for ICP

from spectra.Atomic import Hydrogen
from spectra.Util.AtomUtils.AtomInfo import level_info, extract_lprof, each_prof, line_list
from spectra import Constants as Cst
from spectra.Function.SlabModel import CloudModel

# %% [markdown]
# ## Create atomic model

# %%
# Atomic model
import os

conf_path = os.path.join( CFG._ROOT_DIR, "data/conf/He_I_II.conf" )
atom_He, wMesh_He, path_dict_He = Atom.init_Atom_(conf_path , is_hydrogen=False)
HelpUtil.help_( atom_He )
path_dict_He
# Out:
# ------------------------------------------------------------------------------------------
# name                       type                                 value/len/shape
# ------------------------------------------------------------------------------------------
# Atom
# |- Z                       int                                  v: 2
# |- Mass                    float                                v: 4.0026
# |- Abun                    float                                v: 0.09772372209558111
# |- nLevel                  int                                  v: 21
# |- nLine                   int                                  v: 190
# |- nCont                   int                                  v: 20
# |- nTran                   int                                  v: 210
# |- nRL                     int                                  v: 34
# |- Level                   struct array                         s: (21,)
#   |-  erg                  float64                              s: (21,)
#   |-  g                    int32                                s: (21,)
#   |-  stage                int32                                s: (21,)
#   |-  gamma                float64                              s: (21,)
#   |-  isGround             bool                                 s: (21,)
#   |-  n                    int32                                s: (21,)
# |- Line                    struct array                         s: (190,)
#   |-  idxI                 int32                                s: (190,)
#   |-  idxJ                 int32                                s: (190,)
#   |-  AJI                  float64                              s: (190,)
#   |-  f0                   float64                              s: (190,)
#   |-  w0                   float64                              s: (190,)
#   |-  w0_AA                float64                              s: (190,)
#   |-  Gamma                float64                              s: (190,)
#   |-  gi                   int32                                s: (190,)
#   |-  gj                   int32                                s: (190,)
#   |-  ni                   int32                                s: (190,)
#   |-  nj                   int32                                s: (190,)
#   |-  BJI                  float64                              s: (190,)
#   |-  BIJ                  float64                              s: (190,)
# |- Cont                    struct array                         s: (20,)
#   |-  idxI                 int32                                s: (20,)
#   |-  idxJ                 int32                                s: (20,)
#   |-  f0                   float64                              s: (20,)
#   |-  w0                   float64                              s: (20,)
#   |-  w0_AA                float64                              s: (20,)
#   |-  gi                   int32                                s: (20,)
#   |-  gj                   int32                                s: (20,)
#   |-  ni                   int32                                s: (20,)
#   |-  nj                   int32                                s: (20,)
# |- _has_continuum          bool                                 v: True
# |- _atomic_data_source
#   ATOMIC_DATA_SOURCE
#   |- AJI                   E_ATOMIC_DATA_SOURCE                 v: EXPERIMENT
#   |- CE                    E_ATOMIC_DATA_SOURCE                 v: EXPERIMENT
#   |- CI                    E_ATOMIC_DATA_SOURCE                 v: EXPERIMENT
#   |- PI                    E_ATOMIC_DATA_SOURCE                 v: EXPERIMENT
# |- _atom_type              E_ATOM                               v: NORMAL
# |- _ctj_table
#   CTJ_Table
#   |- Level                 tuple of tuple                       l: 21
#   |- Line                  tuple of tuple                       l: 190
#   |- Cont                  tuple of tuple                       l: 20
# |- _idx_table
#   Index_Table
#   |- Line                  tuple of tuple                       l: 190
#   |- Cont                  tuple of tuple                       l: 20
# |- CE
#   Collisional_Transition
#   |- _transition_type      E_COLLISIONAL_TRANSITION             v: EXCITATION
#   |- _transition_source    E_COLLISIONAL_TRANSITION_SOURCE      v: ELECTRON
#   |- _transition_formula   E_COLLISIONAL_TRANSITION_FORMULA     v: OMEGA
#   |- Te_table              ndarray                              s: (7,)
#   |- Omega_table           ndarray                              s: (190, 7)
#   |- Coe                   struct array                         s: (190,)
#     |-  idxI               int32                                s: (190,)
#     |-  idxJ               int32                                s: (190,)
#     |-  f1                 int32                                s: (190,)
#     |-  f2                 int32                                s: (190,)
#     |-  gi                 int32                                s: (190,)
#     |-  gj                 int32                                s: (190,)
#     |-  dEij               float64                              s: (190,)
# |- CI
#   Collisional_Transition
#   |- _transition_type      E_COLLISIONAL_TRANSITION             v: IONIZATION
#   |- _transition_source    E_COLLISIONAL_TRANSITION_SOURCE      v: ELECTRON
#   |- _transition_formula   E_COLLISIONAL_TRANSITION_FORMULA     v: OMEGA
#   |- Te_table              ndarray                              s: (7,)
#   |- Omega_table           ndarray                              s: (20, 7)
#   |- Coe                   struct array                         s: (20,)
#     |-  idxI               int32                                s: (20,)
#     |-  idxJ               int32                                s: (20,)
#     |-  f1                 int32                                s: (20,)
#     |-  f2                 int32                                s: (20,)
#     |-  gi                 int32                                s: (20,)
#     |-  gj                 int32                                s: (20,)
#     |-  dEij               float64                              s: (20,)
# |- PI
#   Photo_Ionization
#   |- alpha_table           ndarray                              s: (2, 867)
#   |- alpha_table_idxs      ndarray                              s: (20, 2)
#   |- Coe                   struct array                         s: (20,)
#     |-  idxI               int32                                s: (20,)
#     |-  idxJ               int32                                s: (20,)
#     |-  nLambda            int32                                s: (20,)
#     |-  alpha0             float64                              s: (20,)
#     |-  gi                 int32                                s: (20,)
#     |-  gj                 int32                                s: (20,)
#     |-  dEij               float64                              s: (20,)
#   |- alpha_interp          ndarray                              s: (20, 41)
# |- RL
#   Radiative_Line
#   |- nRadiativeLine        int                                  v: 34
#   |- Coe                   struct array                         s: (34,)
#     |-  idxI               int32                                s: (34,)
#     |-  idxJ               int32                                s: (34,)
#     |-  lineIndex          int32                                s: (34,)
#     |-  ProfileType        int32                                s: (34,)
#     |-  qcore              float64                              s: (34,)
#     |-  qwing              float64                              s: (34,)
#     |-  nLambda            int32                                s: (34,)
# {'folder': 'D:\\home\\python\\spectra\\data\\atom\\He',
#  'conf': 'D:\\home\\Python\\spectra\\data\\conf\\He_I_II.conf',
#  'Level': 'D:\\home\\python\\spectra\\data\\atom\\He\\He_I_II.Level',
#  'Aji': 'D:\\home\\python\\spectra\\data\\atom\\He\\He.Aji',
#  'CEe': 'D:\\home\\python\\spectra\\data\\atom\\He\\He.CE.electron',
#  'CIe': 'D:\\home\\python\\spectra\\data\\atom\\He\\He.CI.electron',
#  'PI': 'D:\\home\\python\\spectra\\data\\atom\\He\\He_I_II.Alpha',
#  'RadiativeLine': 'D:\\home\\python\\spectra\\data\\atom\\He\\He_I_II.RadiativeLine',
#  'Grotrian': 'D:\\home\\python\\spectra\\data\\atom\\He\\He.Grotrian'}

# %% [markdown]
# ## He Plasma observation

# %%
import scipy.io as sio

filename = 'D:\data\hida\plasma/sp50w_pscan.sav'   # data on 2022.09.02
d = sio.readsav(filename)
#print(d.date_obs)
print(d.keys())

wlo = d.wl[0:2048] *10    # nm
spo = d.sp50w[2,:]  # W/m^2/nm
# W/m^2/nm  -> erg/cm^3/s/str
spo = spo *10**7 / 10.**4 *10.**7

fig, ax = plt.subplots(1,1, figsize=(8,3), dpi=150)
ax.plot(wlo,spo,label='He')

d.pr
# Out:
# dict_keys(['wl', 'pr', 'sp50w'])
# array([0.4, 0.5, 1. , 2. , 3. , 4. , 5.3], dtype=float32)

# %%
# from spectra.Function.SlabModel import CloudModel
Te = 2E4
Ti = -1
#Pg_pa = 5  # [Pa]
#Pg = Pg_pa * 10 # [dyn/cm^2, cgs]
#Nh = 1*1e11
Ne = 1e10
Vt = 0.            #   cm/s
depth = 20. # cm   6.E3 * 1.E5 #   km *1e5
#stage_pop = np.array([1.,1e-5, 1e-10])  # set to 0 will cause NAN value in solving equation Ax=b

slab = Atmosphere.Atmosphere0D(Nh=0.0, Ne=Ne, Te=Te, Vt=Vt)     # slab 
#slab = Atmosphere.Atmosphere0D(Nh=0.0, Ne=0.0, Te=Te, Vt=Vt, Pg=Pg, Ti=Ti)
radiation = Radiation.init_Radiation_()
radiation.solar[1,:] = 0.0     # no incident intensity for b-b transition (was: backRad[1,:] = 0.0)

#SE_He, Rate_He = SELib.cal_SE_with_Nh_Te_(atom_He, slab, wMesh_He, solar_spec_He, None) # SE_H.n_SE)  #  level populations etc.
#SE_He, Rate_He = SELib.cal_SE_with_Pg_Te_single_Atom_(atom_He, slab, wMesh_He, radiation)#, stage_pop)
SE_He, Rate_He = SELib.cal_SE_with_Ne_Te_(atom_He, slab, wMesh_He, radiation, 
                                          None, is_single_element=True)

lHe = CloudModel.SE_to_slab_0D_(atom_He, slab, SE_He, depth=depth)      # hydrogen lines intensity
# Out:
# D:\home\Python\spectra\spectra\Function\SlabModel\CloudModel.py:47: RuntimeWarning: invalid value encountered in true_divide
#   Src   : T_ARRAY = ( Aji * nj ) / ( Bij * ni - Bji * nj )

# %%
# check result population 
for i in range(3):
    res = (SE_He.n_SE * (atom_He.Level['stage']==i+1)).sum()
    print(f"sum of the population of stage {i+1} = {res}")

SE_He.n_SE
# Out:
# sum of the population of stage 1 = 0.9665443721678596
# sum of the population of stage 2 = 0.03345562783214069
# sum of the population of stage 3 = 0.0
# array([9.66541898e-01, 2.32540539e-06, 1.41826809e-07, 3.59049815e-09,
#        2.15429091e-09, 7.18151258e-10, 2.09533307e-12, 1.74591756e-11,
#        1.46686272e-11, 2.66160946e-11, 2.46786315e-12, 1.76275958e-12,
#        1.05766841e-12, 1.81237919e-12, 2.06378662e-13, 3.02993523e-12,
#        2.85612474e-12, 3.62773584e-12, 1.19404909e-12, 4.04565936e-13,
#        3.34556278e-02])

# %%
f"{slab.Nh:.2E}",f"{slab.Ne:.2E}"
# Out:
# ('1.10E+10', '1.00E+10')

# %%
# to check line width
plt.plot(SE_He.wave_mesh_shifted_1d[0:40]*1E8, SE_He.absorb_prof_1d[0:40])

# %%
fig, ax = plt.subplots(1,1, figsize=(8,3), dpi=150)


ax.plot(wlo,spo,label='experi')
ax.plot(lHe.wl_1D*1e8,lHe.prof_1D,'-',label='Calc')
#ax.set_ylim(1e9,1E14)
#ax.set_xlim(500, 50000)
#ax.set_xscale("log")
ax.set_xlim(3000, 11000)
ax.set_yscale("log")
ax.set_ylim(1e4, 1e15)
#ax.set_ylim(0, 6e7)
ax.set_xlabel("wavelength [A]", fontsize=12)
ax.set_ylabel("intensity [erg/cm^3/s/str]", fontsize=12)
plt.title("He plasma; $T_e$={0:5.0f}K, $P_g$={1:5.1e}dyn/cm$^{{2}}$".format(Te, Pg),fontsize=13)
ax.legend(fontsize=8,ncol=1)
plt.show()

# %%
atom_He.Line['w0_AA'][0]
# Out:
# 625.5629940686423

# %% [raw]
# def line_list(atom, Aji_min = 1E4):
#     selects = []
#     for i in range(atom.nLine):
#         wv0 = atom.Line['w0_AA'][i]
#         Aji = atom.Line['AJI'][i]
#         if Aji < Aji_min: continue
#         ctj1, ctj2 = atom._ctj_table.Line[i]
#         #print(f"{i:3d}  wavelength={wv0:10.2F}[A]  Aji={Aji:.1E}    {ctj1}<--{ctj2}")
#         selects.append( {'id':i, 'w0_AA':wv0, 'Aji':Aji, 'ctj1':ctj1, 'ctj2':ctj2} )
#     selects = sorted(selects, key=lambda x: x['w0_AA'])
#     print(f"id   wavelength[A]  Aji[s-1]   lower level ctj    -     upper level ctj ")
#     for sel in selects:
#         id = sel['id']
#         wv0 = sel['w0_AA']
#         Aji = sel['Aji']
#         ctj1 = sel['ctj1']
#         ctj2 = sel['ctj2']
#         #print(f"wavelength={wv0:10.2F}[A]  Aji={Aji:.1E}    {ctj1}<--{ctj2}")
#         print(f"{id:3d}  {wv0:10.2F}  {Aji:.1E}    {ctj1}  -  {ctj2}")
#     print(f"# selected = {len(selects)}")
#     return(selects)

# %%
#for i in 
atom = atom_He
l = line_list(atom)
# Out:
# id   wavelength[A]  Aji[s-1]   lower level ctj    -     upper level ctj
# 193      256.32  3.0E+09    ('1s', '2S', '1/2')  -  ('3p', '2P', '1/2+3/2')
# 191      303.78  1.0E+10    ('1s', '2S', '1/2')  -  ('2p', '2P', '1/2+3/2')
#  13      537.03  5.9E+08    ('1s2', '1S', '0')  -  ('1s.3p', '1P', '1')
#   5      584.33  1.8E+09    ('1s2', '1S', '0')  -  ('1s.2p', '1P', '1')
# 197     1640.36  3.0E+09    ('2s', '2S', '1/2')  -  ('3p', '2P', '1/2+3/2')
# 200     1640.45  1.0E+09    ('2p', '2P', '1/2+3/2')  -  ('3p', '2P', '1/2+3/2')
# 199     1640.48  1.0E+08    ('2p', '2P', '1/2+3/2')  -  ('3s', '2S', '1/2')
#  34     3188.66  7.2E+06    ('1s.2s', '3S', '1')  -  ('1s.4p', '3P', '2+1+0')
#  26     3889.74  1.0E+07    ('1s.2s', '3S', '1')  -  ('1s.3p', '3P', '2+1+0')
#  68     4472.73  3.1E+07    ('1s.2p', '3P', '2')  -  ('1s.4d', '3D', '3+2+1')
#  65     4714.46  1.6E+07    ('1s.2p', '3P', '2')  -  ('1s.4s', '3S', '1')
# 111     4923.30  2.7E+07    ('1s.2p', '1P', '1')  -  ('1s.4d', '1D', '2')
#  48     5017.08  5.9E+08    ('1s.2s', '1S', '0')  -  ('1s.3p', '1P', '1')
# 108     5049.15  1.1E+07    ('1s.2p', '1P', '1')  -  ('1s.4s', '1S', '0')
#  62     5877.23  2.0E+06    ('1s.2p', '3P', '2')  -  ('1s.3d', '3D', '1')
#  61     5877.24  1.8E+07    ('1s.2p', '3P', '2')  -  ('1s.3d', '3D', '2')
#  60     5877.24  7.1E+07    ('1s.2p', '3P', '2')  -  ('1s.3d', '3D', '3')
#  77     5877.25  2.9E+07    ('1s.2p', '3P', '1')  -  ('1s.3d', '3D', '1')
#  76     5877.27  5.3E+07    ('1s.2p', '3P', '1')  -  ('1s.3d', '3D', '2')
#  91     5877.59  3.9E+07    ('1s.2p', '3P', '0')  -  ('1s.3d', '3D', '1')
# 105     6679.99  6.4E+07    ('1s.2p', '1P', '1')  -  ('1s.3d', '1D', '2')
#  57     7067.12  2.8E+07    ('1s.2p', '3P', '2')  -  ('1s.3s', '3S', '1')
# 100     7283.36  1.8E+07    ('1s.2p', '1P', '1')  -  ('1s.3s', '1S', '0')
#  22    10832.06  1.0E+07    ('1s.2s', '3S', '1')  -  ('1s.2p', '3P', '0')
#  21    10833.21  1.0E+07    ('1s.2s', '3S', '1')  -  ('1s.2p', '3P', '1')
#  20    10833.30  1.0E+07    ('1s.2s', '3S', '1')  -  ('1s.2p', '3P', '2')
# 121    12530.91  7.2E+06    ('1s.3s', '3S', '1')  -  ('1s.4p', '3P', '2+1+0')
# 143    17007.14  3.1E+07    ('1s.3p', '3P', '2+1+0')  -  ('1s.4d', '3D', '3+2+1')
# 179    19094.57  2.7E+07    ('1s.3p', '1P', '1')  -  ('1s.4d', '1D', '2')
# 151    19548.39  7.2E+06    ('1s.3d', '3D', '3')  -  ('1s.4p', '3P', '2+1+0')
#  40    20586.90  1.8E+09    ('1s.2s', '1S', '0')  -  ('1s.2p', '1P', '1')
# 140    21125.96  1.6E+07    ('1s.3p', '3P', '2+1+0')  -  ('1s.4s', '3S', '1')
# 176    21137.80  1.1E+07    ('1s.3p', '1P', '1')  -  ('1s.4s', '1S', '0')
# 113    42958.82  1.0E+07    ('1s.3s', '3S', '1')  -  ('1s.3p', '3P', '2+1+0')
# 129    74375.11  5.9E+08    ('1s.3s', '1S', '0')  -  ('1s.3p', '1P', '1')
# 181   108820.54  7.2E+06    ('1s.4s', '3S', '1')  -  ('1s.4p', '3P', '2+1+0')
# 135   186238.98  7.1E+07    ('1s.3p', '3P', '2+1+0')  -  ('1s.3d', '3D', '3')
# 187   439699.42  3.1E+07    ('1s.4p', '3P', '2+1+0')  -  ('1s.4d', '3D', '3+2+1')
# 169   957870.29  5.9E+08    ('1s.3d', '1D', '2')  -  ('1s.3p', '1P', '1')
# # selected = 39

# %%
# Out:
# dict_keys(['wl', 'pr', 'sp50w'])
