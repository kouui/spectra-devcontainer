# %%
import numpy as np                # module for vectorized numeric calculation
import sys
from sympy import *
import sympy as sp
from IPython.display import Math
init_printing()

# %%
g, H, w, k, Q = sp.symbols('g H omega k Q', real=True)
Q = H*g+w/k
Q
# Out:
#       ω
# H⋅g + ─
#       k

# %%
Q.subs([(H,k**2)])
# Out:
#    2   ω
# g⋅k  + ─
#        k
